# %%
from utils import clean_data

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from utils import load_data

titanic = load_data()
print(titanic.head(10))
# Out:
#     pclass  survived                                  name   sex      age  \
# 1        1         1        Allison, Master. Hudson Trevor  male   0.9167
# 3        1         0  Allison, Mr. Hudson Joshua Creighton  male  30.0000
# 5        1         1                   Anderson, Mr. Harry  male  48.0000
# 7        1         0                Andrews, Mr. Thomas Jr  male  39.0000
# 9        1         0               Artagaveytia, Mr. Ramon  male  71.0000
# 10       1         0                Astor, Col. John Jacob  male  47.0000
# 14       1         1  Barkworth, Mr. Algernon Henry Wilson  male  80.0000
# 15       1         0                   Baumann, Mr. John D  male      NaN
# 16       1         0              Baxter, Mr. Quigg Edmond  male  24.0000
# 19       1         0                  Beattie, Mr. Thomson  male  36.0000
#
#     sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 1       1      2    113781  151.5500  C22 C26        S   11    NaN
# ...

# %%
titanic_cleaned = clean_data(titanic) # navigator adds
titanic_cleaned['pclass'].value_counts().plot(kind='bar') # navigator adds
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 titanic_cleaned = clean_data(titanic) # navigator adds
# ----> 2 titanic_cleaned['pclass'].value_counts().plot(kind='bar') # navigator adds
#
# File ~/Documents/HWR/Git_exercise/.venv/lib/python3.9/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/Documents/HWR/Git_exercise/.venv/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
# ...

# %%
titanic_cleaned['Age'].plot(kind='hist', bins=20) # driver adds
